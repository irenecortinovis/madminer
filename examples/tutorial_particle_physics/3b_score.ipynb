# %% [markdown]
# # MadMiner particle physics tutorial
#
# # Part 3b: Training a score estimator
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In part 3a of this tutorial we will finally train a neural network to estimate likelihood ratios. We assume that you have run part 1 and 2a of this tutorial. If, instead of 2a, you have run part 2b, you just have to load a different filename later.

# %% [markdown]
# ## Preparations

# %% [markdown]
# Make sure you've run the first tutorial before executing this notebook!

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

from madminer.sampling import SampleAugmenter
from madminer import sampling
from madminer.ml import ScoreEstimator

# %%
# MadMiner output
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.INFO
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Make (unweighted) training and test samples with augmented data

# %% [markdown]
# At this point, we have all the information we need from the simulations. But the data is not quite ready to be used for machine learning. The `madminer.sampling` class `SampleAugmenter` will take care of the remaining book-keeping steps before we can train our estimators:
#
# First, it unweights the samples, i.e. for a given parameter vector `theta` (or a distribution `p(theta)`) it picks events `x` such that their distribution follows `p(x|theta)`. The selected samples will all come from the event file we have so far, but their frequency is changed -- some events will appear multiple times, some will disappear.
#
# Second, `SampleAugmenter` calculates all the augmented data ("gold") that is the key to our new inference methods. Depending on the specific technique, these are the joint likelihood ratio and / or the joint score. It saves all these pieces of information for the selected events in a set of numpy files that can easily be used in any machine learning framework.

# %%
sampler = SampleAugmenter('data/lhe_data_shuffled.h5')
# sampler = SampleAugmenter('data/delphes_data_shuffled.h5')
# Out:
# 17:26 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 17:26 madminer.analysis    INFO    Found 2 parameters
# 17:26 madminer.analysis    INFO    Did not find nuisance parameters
# 17:26 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 17:26 madminer.analysis    INFO    Found 3 observables
# 17:26 madminer.analysis    INFO    Found 89995 events
# 17:26 madminer.analysis    INFO      49995 signal events sampled from benchmark sm
# 17:26 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 17:26 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 17:26 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 17:26 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 17:26 madminer.analysis    INFO    Found morphing setup with 6 components
# 17:26 madminer.analysis    INFO    Did not find nuisance morphing setup

# %% [markdown]
# The relevant `SampleAugmenter` function for local score estimators is `extract_samples_train_local()`. As in part 3a of the tutorial, for the argument `theta` you can use the helper functions `sampling.benchmark()`, `sampling.benchmarks()`, `sampling.morphing_point()`, `sampling.morphing_points()`, and `sampling.random_morphing_points()`.

# %%
x, theta, t_xz, _ = sampler.sample_train_local(
    theta=sampling.benchmark('sm'),
    n_samples=500000,
    folder='./data/samples',
    filename='train_score'
)
# Out:
# 17:26 madminer.sampling    INFO    Extracting training sample for local score regression. Sampling and score evaluation according to sm
# 17:26 madminer.sampling    INFO    Starting sampling serially
# 17:26 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 17:26 madminer.sampling    INFO    Effective number of samples: mean 30015.0, with individual thetas ranging from 30015.0 to 30015.0

# %% [markdown]
# We can use the same data as in part 3a, so you only have to execute this if you haven't gone through tutorial 3a:

# %%
_ = sampler.sample_test(
    theta=sampling.benchmark('sm'),
    n_samples=1000,
    folder='./data/samples',
    filename='test'
)
# Out:
# 17:26 madminer.sampling    INFO    Extracting evaluation sample. Sampling according to sm
# 17:26 madminer.sampling    INFO    Starting sampling serially
# 17:26 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 17:26 madminer.sampling    INFO    Effective number of samples: mean 9936.000000000002, with individual thetas ranging from 9936.000000000002 to 9936.000000000002

# %% [markdown]
# ## 2. Train score estimator

# %% [markdown]
# It's now time to build a neural network. Only this time, instead of the likelihood ratio itself, we will estimate the gradient of the log likelihood with respect to the theory parameters -- the score. To be precise, the output of the neural network is an estimate of the score at some reference parameter point, for instance the Standard Model. A neural network that estimates this "local" score can be used to calculate the Fisher information at that point. The estimated score can also be used as a machine learning version of Optimal Observables, and likelihoods can be estimated based on density estimation in the estimated score space. This method for likelihood ratio estimation is called SALLY, and there is a closely related version called SALLINO. Both are explained in ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013) and ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020).
#
# The central object for this is the `madminer.ml.ScoreEstimator` class:

# %%
estimator = ScoreEstimator(n_hidden=(30,30))

# %%
estimator.train(
    method='sally',
    x='data/samples/x_train_score.npy',
    t_xz='data/samples/t_xz_train_score.npy',
)

estimator.save('models/sally')
# Out:
# 17:26 madminer.ml          INFO    Starting training
# 17:26 madminer.ml          INFO      Batch size:             128
# 17:26 madminer.ml          INFO      Optimizer:              amsgrad
# 17:26 madminer.ml          INFO      Epochs:                 50
# 17:26 madminer.ml          INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 17:26 madminer.ml          INFO      Validation split:       0.25
# 17:26 madminer.ml          INFO      Early stopping:         True
# 17:26 madminer.ml          INFO      Scale inputs:           True
# 17:26 madminer.ml          INFO      Shuffle labels          False
# 17:26 madminer.ml          INFO      Samples:                all
# 17:26 madminer.ml          INFO    Loading training data
# 17:26 madminer.utils.vario INFO      Loading data/samples/x_train_score.npy into RAM
# 17:26 madminer.utils.vario INFO      Loading data/samples/t_xz_train_score.npy into RAM
# 17:26 madminer.ml          INFO    Found 500000 samples with 2 parameters and 3 observables
# 17:26 madminer.ml          INFO    Setting up input rescaling
# 17:26 madminer.ml          INFO    Creating model
# 17:26 madminer.ml          INFO    Training model
# 17:26 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 17:27 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.17740 (mse_score:  0.177)
# 17:27 madminer.utils.ml.tr INFO                 val. loss   0.17347 (mse_score:  0.173)
# 17:28 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.16906 (mse_score:  0.169)
# 17:28 madminer.utils.ml.tr INFO                 val. loss   0.16648 (mse_score:  0.166)
# 17:28 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.16517 (mse_score:  0.165)
# 17:28 madminer.utils.ml.tr INFO                 val. loss   0.16210 (mse_score:  0.162)
# 17:29 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.16236 (mse_score:  0.162)
# 17:29 madminer.utils.ml.tr INFO                 val. loss   0.16028 (mse_score:  0.160)
# 17:30 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.16001 (mse_score:  0.160)
# 17:30 madminer.utils.ml.tr INFO                 val. loss   0.15864 (mse_score:  0.159)
# 17:31 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.15826 (mse_score:  0.158)
# 17:31 madminer.utils.ml.tr INFO                 val. loss   0.15791 (mse_score:  0.158)
# 17:31 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.15667 (mse_score:  0.157)
# 17:31 madminer.utils.ml.tr INFO                 val. loss   0.15700 (mse_score:  0.157)
# 17:32 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.15566 (mse_score:  0.156)
# 17:32 madminer.utils.ml.tr INFO                 val. loss   0.15575 (mse_score:  0.156)
# 17:33 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.15446 (mse_score:  0.154)
# 17:33 madminer.utils.ml.tr INFO                 val. loss   0.15768 (mse_score:  0.158)
# 17:33 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.15355 (mse_score:  0.154)
# 17:33 madminer.utils.ml.tr INFO                 val. loss   0.15415 (mse_score:  0.154)
# 17:34 madminer.utils.ml.tr INFO      Epoch  22: train loss  0.15278 (mse_score:  0.153)
# 17:34 madminer.utils.ml.tr INFO                 val. loss   0.15371 (mse_score:  0.154)
# 17:35 madminer.utils.ml.tr INFO      Epoch  24: train loss  0.15219 (mse_score:  0.152)
# 17:35 madminer.utils.ml.tr INFO                 val. loss   0.15323 (mse_score:  0.153)
# 17:35 madminer.utils.ml.tr INFO      Epoch  26: train loss  0.15157 (mse_score:  0.152)
# 17:35 madminer.utils.ml.tr INFO                 val. loss   0.15343 (mse_score:  0.153)
# 17:36 madminer.utils.ml.tr INFO      Epoch  28: train loss  0.15105 (mse_score:  0.151)
# 17:36 madminer.utils.ml.tr INFO                 val. loss   0.15423 (mse_score:  0.154)
# 17:37 madminer.utils.ml.tr INFO      Epoch  30: train loss  0.15062 (mse_score:  0.151)
# 17:37 madminer.utils.ml.tr INFO                 val. loss   0.15229 (mse_score:  0.152)
# 17:37 madminer.utils.ml.tr INFO      Epoch  32: train loss  0.15012 (mse_score:  0.150)
# 17:37 madminer.utils.ml.tr INFO                 val. loss   0.15105 (mse_score:  0.151)
# 17:38 madminer.utils.ml.tr INFO      Epoch  34: train loss  0.14981 (mse_score:  0.150)
# 17:38 madminer.utils.ml.tr INFO                 val. loss   0.15129 (mse_score:  0.151)
# 17:39 madminer.utils.ml.tr INFO      Epoch  36: train loss  0.14930 (mse_score:  0.149)
# 17:39 madminer.utils.ml.tr INFO                 val. loss   0.15047 (mse_score:  0.150)
# 17:40 madminer.utils.ml.tr INFO      Epoch  38: train loss  0.14910 (mse_score:  0.149)
# 17:40 madminer.utils.ml.tr INFO                 val. loss   0.15075 (mse_score:  0.151)
# 17:40 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.14879 (mse_score:  0.149)
# 17:40 madminer.utils.ml.tr INFO                 val. loss   0.15013 (mse_score:  0.150)
# 17:41 madminer.utils.ml.tr INFO      Epoch  42: train loss  0.14851 (mse_score:  0.149)
# 17:41 madminer.utils.ml.tr INFO                 val. loss   0.15032 (mse_score:  0.150)
# 17:42 madminer.utils.ml.tr INFO      Epoch  44: train loss  0.14835 (mse_score:  0.148)
# 17:42 madminer.utils.ml.tr INFO                 val. loss   0.14980 (mse_score:  0.150)
# 17:42 madminer.utils.ml.tr INFO      Epoch  46: train loss  0.14812 (mse_score:  0.148)
# 17:42 madminer.utils.ml.tr INFO                 val. loss   0.14970 (mse_score:  0.150)
# 17:43 madminer.utils.ml.tr INFO      Epoch  48: train loss  0.14796 (mse_score:  0.148)
# 17:43 madminer.utils.ml.tr INFO                 val. loss   0.14940 (mse_score:  0.149)
# 17:44 madminer.utils.ml.tr INFO      Epoch  50: train loss  0.14780 (mse_score:  0.148)
# 17:44 madminer.utils.ml.tr INFO                 val. loss   0.14945 (mse_score:  0.149)
# 17:44 madminer.utils.ml.tr INFO    Early stopping after epoch 49, with loss  0.14922 compared to final loss  0.14945
# 17:44 madminer.utils.ml.tr INFO    Training time spend on:
# 17:44 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 17:44 madminer.utils.ml.tr INFO                                   ALL:   0.29h
# 17:44 madminer.utils.ml.tr INFO                            check data:   0.00h
# 17:44 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 17:44 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 17:44 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 17:44 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 17:44 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 17:44 madminer.utils.ml.tr INFO                   load training batch:   0.12h
# 17:44 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 17:44 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.02h
# 17:44 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.02h
# 17:44 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.01h
# 17:44 madminer.utils.ml.tr INFO                 training forward pass:   0.04h
# 17:44 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 17:44 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 17:44 madminer.utils.ml.tr INFO                         opt: backward:   0.03h
# 17:44 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 17:44 madminer.utils.ml.tr INFO                             opt: step:   0.05h
# 17:44 madminer.utils.ml.tr INFO                        optimizer step:   0.08h
# 17:44 madminer.utils.ml.tr INFO                 load validation batch:   0.04h
# 17:44 madminer.utils.ml.tr INFO               validation forward pass:   0.01h
# 17:44 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 17:44 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 17:44 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 17:44 madminer.ml          INFO    Saving model to models/sally

# %% [markdown]
# ## 3. Evaluate score estimator

# %% [markdown]
# Let's evaluate the SM score on the test data

# %%
estimator.load('models/sally')

t_hat = estimator.evaluate_score(
    x='data/samples/x_test.npy'
)
# Out:
# 17:44 madminer.ml          INFO    Loading model from models/sally
# 17:44 madminer.ml          INFO    Loading evaluation data
# 17:44 madminer.utils.vario INFO      Loading data/samples/x_test.npy into RAM
# 17:44 madminer.ml          INFO    Starting score evaluation

# %% [markdown]
# Let's have a look at the estimated score and how it is related to the observables:

# %%
x = np.load('data/samples/x_test.npy')

fig = plt.figure(figsize=(10,4))

for i in range(2):
    
    ax = plt.subplot(1,2,i+1)

    sc = plt.scatter(x[:,0], x[:,1], c=t_hat[:,i], s=25., cmap='viridis', vmin=-1., vmax=1.)
    cbar = plt.colorbar(sc)

    cbar.set_label(r'$\hat{t}_' + str(i) + r'(x | \theta_{ref})$')
    plt.xlabel(r'$p_{T,j1}$ [GeV]')
    plt.ylabel(r'$\Delta \phi_{jj}$')
    plt.xlim(10.,300.)
    plt.ylim(-3.15,3.15)
    
plt.tight_layout()
plt.show()
