# %% [markdown]
# # MadMiner particle physics tutorial
#
# # Part 3b: Training a score estimator
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In part 3a of this tutorial we will finally train a neural network to estimate likelihood ratios. We assume that you have run part 1 and 2a of this tutorial. If, instead of 2a, you have run part 2b, you just have to load a different filename later.

# %% [markdown]
# ## Preparations

# %% [markdown]
# Make sure you've run the first tutorial before executing this notebook!

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

from madminer.sampling import SampleAugmenter
from madminer import sampling
from madminer.ml import ScoreEstimator

# %%
# MadMiner output
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.INFO
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Make (unweighted) training and test samples with augmented data

# %% [markdown]
# At this point, we have all the information we need from the simulations. But the data is not quite ready to be used for machine learning. The `madminer.sampling` class `SampleAugmenter` will take care of the remaining book-keeping steps before we can train our estimators:
#
# First, it unweights the samples, i.e. for a given parameter vector `theta` (or a distribution `p(theta)`) it picks events `x` such that their distribution follows `p(x|theta)`. The selected samples will all come from the event file we have so far, but their frequency is changed -- some events will appear multiple times, some will disappear.
#
# Second, `SampleAugmenter` calculates all the augmented data ("gold") that is the key to our new inference methods. Depending on the specific technique, these are the joint likelihood ratio and / or the joint score. It saves all these pieces of information for the selected events in a set of numpy files that can easily be used in any machine learning framework.

# %%
# sampler = SampleAugmenter('data/lhe_data_shuffled.h5')
sampler = SampleAugmenter('data_pp/delphes_data_shuffled.h5')
# Out:
# 15:58 madminer.analysis.da INFO    Loading data from data_pp/delphes_data_shuffled.h5
# 15:58 madminer.analysis.da INFO    Found 2 parameters
# 15:58 madminer.analysis.da INFO    Did not find nuisance parameters
# 15:58 madminer.analysis.da INFO    Found 6 benchmarks, of which 6 physical
# 15:58 madminer.analysis.da INFO    Found 12 observables
# 15:58 madminer.analysis.da INFO    Found 116651 events
# 15:58 madminer.analysis.da INFO      60564 signal events sampled from benchmark sm
# 15:58 madminer.analysis.da INFO      14606 signal events sampled from benchmark w
# 15:58 madminer.analysis.da INFO      14611 signal events sampled from benchmark neg_w
# 15:58 madminer.analysis.da INFO      13316 signal events sampled from benchmark ww
# 15:58 madminer.analysis.da INFO      13554 signal events sampled from benchmark neg_ww
# 15:58 madminer.analysis.da INFO    Found morphing setup with 6 components
# 15:58 madminer.analysis.da INFO    Did not find nuisance morphing setup

# %% [markdown]
# The relevant `SampleAugmenter` function for local score estimators is `extract_samples_train_local()`. As in part 3a of the tutorial, for the argument `theta` you can use the helper functions `sampling.benchmark()`, `sampling.benchmarks()`, `sampling.morphing_point()`, `sampling.morphing_points()`, and `sampling.random_morphing_points()`.

# %%
x, theta, t_xz, _ = sampler.sample_train_local(
    theta=sampling.benchmark('sm'),
    n_samples=500000,
    folder='./data_pp/samples',
    filename='train_score'
)
# Out:
# 15:58 madminer.sampling.sa INFO    Extracting training sample for local score regression. Sampling and score evaluation according to sm
# 15:58 madminer.sampling.sa INFO    Starting sampling serially
# 15:58 madminer.sampling.sa INFO    Sampling from parameter point 1 / 1
# 15:58 madminer.sampling.sa INFO    Effective number of samples: mean 36182.00000000001, with individual thetas ranging from 36182.00000000001 to 36182.00000000001

# %% [markdown]
# We can use the same data as in part 3a, so you only have to execute this if you haven't gone through tutorial 3a:

# %%
_ = sampler.sample_test(
    theta=sampling.benchmark('sm'),
    n_samples=1000,
    folder='./data_pp/samples',
    filename='test'
)
# Out:
# 15:58 madminer.sampling.sa INFO    Extracting evaluation sample. Sampling according to sm
# 15:58 madminer.sampling.sa INFO    Starting sampling serially
# 15:58 madminer.sampling.sa INFO    Sampling from parameter point 1 / 1
# 15:58 madminer.sampling.sa INFO    Effective number of samples: mean 12204.000000000002, with individual thetas ranging from 12204.000000000002 to 12204.000000000002

# %% [markdown]
# ## 2. Train score estimator

# %% [markdown]
# It's now time to build a neural network. Only this time, instead of the likelihood ratio itself, we will estimate the gradient of the log likelihood with respect to the theory parameters -- the score. To be precise, the output of the neural network is an estimate of the score at some reference parameter point, for instance the Standard Model. A neural network that estimates this "local" score can be used to calculate the Fisher information at that point. The estimated score can also be used as a machine learning version of Optimal Observables, and likelihoods can be estimated based on density estimation in the estimated score space. This method for likelihood ratio estimation is called SALLY, and there is a closely related version called SALLINO. Both are explained in ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013) and ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020).
#
# The central object for this is the `madminer.ml.ScoreEstimator` class:

# %%
estimator = ScoreEstimator(n_hidden=(30,30))

# %%
estimator.train(
    method='sally',
    x='data_pp/samples/x_train_score.npy',
    t_xz='data_pp/samples/t_xz_train_score.npy',
)

estimator.save('models/sally')
# Out:
# 15:58 madminer.ml.score    INFO    Starting training
# 15:58 madminer.ml.score    INFO      Batch size:             128
# 15:58 madminer.ml.score    INFO      Optimizer:              amsgrad
# 15:58 madminer.ml.score    INFO      Epochs:                 50
# 15:58 madminer.ml.score    INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 15:58 madminer.ml.score    INFO      Validation split:       0.25
# 15:58 madminer.ml.score    INFO      Early stopping:         True
# 15:58 madminer.ml.score    INFO      Scale inputs:           True
# 15:58 madminer.ml.score    INFO      Shuffle labels          False
# 15:58 madminer.ml.score    INFO      Samples:                all
# 15:58 madminer.ml.score    INFO    Loading training data
# 15:58 madminer.utils.vario INFO      Loading data_pp/samples/x_train_score.npy into RAM
# 15:58 madminer.utils.vario INFO      Loading data_pp/samples/t_xz_train_score.npy into RAM
# 15:58 madminer.ml.score    INFO    Found 500000 samples with 2 parameters and 12 observables
# 15:58 madminer.ml.base     INFO    Setting up input rescaling
# 15:58 madminer.ml.score    INFO    Creating model
# 15:58 madminer.ml.score    INFO    Training model
# 15:58 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 15:59 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.08996 (mse_score:  0.090)
# 15:59 madminer.utils.ml.tr INFO                 val. loss   0.08868 (mse_score:  0.089)
# 16:00 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.08666 (mse_score:  0.087)
# 16:00 madminer.utils.ml.tr INFO                 val. loss   0.08636 (mse_score:  0.086)
# 16:01 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.08596 (mse_score:  0.086)
# 16:01 madminer.utils.ml.tr INFO                 val. loss   0.08566 (mse_score:  0.086)
# 16:02 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.08560 (mse_score:  0.086)
# 16:02 madminer.utils.ml.tr INFO                 val. loss   0.08548 (mse_score:  0.085)
# 16:02 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.08530 (mse_score:  0.085)
# 16:02 madminer.utils.ml.tr INFO                 val. loss   0.08547 (mse_score:  0.085)
# 16:03 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.08506 (mse_score:  0.085)
# 16:03 madminer.utils.ml.tr INFO                 val. loss   0.08500 (mse_score:  0.085)
# 16:04 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.08482 (mse_score:  0.085)
# 16:04 madminer.utils.ml.tr INFO                 val. loss   0.08467 (mse_score:  0.085)
# 16:05 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.08460 (mse_score:  0.085)
# 16:05 madminer.utils.ml.tr INFO                 val. loss   0.08459 (mse_score:  0.085)
# 16:06 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.08445 (mse_score:  0.084)
# 16:06 madminer.utils.ml.tr INFO                 val. loss   0.08444 (mse_score:  0.084)
# 16:07 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.08429 (mse_score:  0.084)
# 16:07 madminer.utils.ml.tr INFO                 val. loss   0.08429 (mse_score:  0.084)
# 16:08 madminer.utils.ml.tr INFO      Epoch  22: train loss  0.08415 (mse_score:  0.084)
# 16:08 madminer.utils.ml.tr INFO                 val. loss   0.08402 (mse_score:  0.084)
# 16:09 madminer.utils.ml.tr INFO      Epoch  24: train loss  0.08399 (mse_score:  0.084)
# 16:09 madminer.utils.ml.tr INFO                 val. loss   0.08405 (mse_score:  0.084)
# 16:10 madminer.utils.ml.tr INFO      Epoch  26: train loss  0.08388 (mse_score:  0.084)
# 16:10 madminer.utils.ml.tr INFO                 val. loss   0.08400 (mse_score:  0.084)
# 16:11 madminer.utils.ml.tr INFO      Epoch  28: train loss  0.08374 (mse_score:  0.084)
# 16:11 madminer.utils.ml.tr INFO                 val. loss   0.08398 (mse_score:  0.084)
# 16:12 madminer.utils.ml.tr INFO      Epoch  30: train loss  0.08363 (mse_score:  0.084)
# 16:12 madminer.utils.ml.tr INFO                 val. loss   0.08387 (mse_score:  0.084)
# 16:13 madminer.utils.ml.tr INFO      Epoch  32: train loss  0.08357 (mse_score:  0.084)
# 16:13 madminer.utils.ml.tr INFO                 val. loss   0.08364 (mse_score:  0.084)
# 16:14 madminer.utils.ml.tr INFO      Epoch  34: train loss  0.08346 (mse_score:  0.083)
# 16:14 madminer.utils.ml.tr INFO                 val. loss   0.08353 (mse_score:  0.084)
# 16:15 madminer.utils.ml.tr INFO      Epoch  36: train loss  0.08340 (mse_score:  0.083)
# 16:15 madminer.utils.ml.tr INFO                 val. loss   0.08353 (mse_score:  0.084)
# 16:16 madminer.utils.ml.tr INFO      Epoch  38: train loss  0.08334 (mse_score:  0.083)
# 16:16 madminer.utils.ml.tr INFO                 val. loss   0.08354 (mse_score:  0.084)
# 16:17 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.08328 (mse_score:  0.083)
# 16:17 madminer.utils.ml.tr INFO                 val. loss   0.08334 (mse_score:  0.083)
# 16:17 madminer.utils.ml.tr INFO      Epoch  42: train loss  0.08323 (mse_score:  0.083)
# 16:17 madminer.utils.ml.tr INFO                 val. loss   0.08344 (mse_score:  0.083)
# 16:18 madminer.utils.ml.tr INFO      Epoch  44: train loss  0.08317 (mse_score:  0.083)
# 16:18 madminer.utils.ml.tr INFO                 val. loss   0.08328 (mse_score:  0.083)
# 16:19 madminer.utils.ml.tr INFO      Epoch  46: train loss  0.08315 (mse_score:  0.083)
# 16:19 madminer.utils.ml.tr INFO                 val. loss   0.08330 (mse_score:  0.083)
# 16:19 madminer.utils.ml.tr INFO      Epoch  48: train loss  0.08310 (mse_score:  0.083)
# 16:19 madminer.utils.ml.tr INFO                 val. loss   0.08320 (mse_score:  0.083)
# 16:20 madminer.utils.ml.tr INFO      Epoch  50: train loss  0.08307 (mse_score:  0.083)
# 16:20 madminer.utils.ml.tr INFO                 val. loss   0.08319 (mse_score:  0.083)
# 16:20 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 16:20 madminer.utils.ml.tr INFO    Training time spend on:
# 16:20 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 16:20 madminer.utils.ml.tr INFO                                   ALL:   0.37h
# 16:20 madminer.utils.ml.tr INFO                            check data:   0.00h
# 16:20 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 16:20 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 16:20 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 16:20 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 16:20 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 16:20 madminer.utils.ml.tr INFO                   load training batch:   0.13h
# 16:20 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 16:20 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.02h
# 16:20 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.03h
# 16:20 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.01h
# 16:20 madminer.utils.ml.tr INFO                 training forward pass:   0.04h
# 16:20 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 16:20 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 16:20 madminer.utils.ml.tr INFO                         opt: backward:   0.08h
# 16:20 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 16:20 madminer.utils.ml.tr INFO                             opt: step:   0.05h
# 16:20 madminer.utils.ml.tr INFO                        optimizer step:   0.13h
# 16:20 madminer.utils.ml.tr INFO                 load validation batch:   0.04h
# 16:20 madminer.utils.ml.tr INFO               validation forward pass:   0.01h
# 16:20 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 16:20 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 16:20 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 16:20 madminer.ml.base     INFO    Saving model to models/sally

# %% [markdown]
# ## 3. Evaluate score estimator

# %% [markdown]
# Let's evaluate the SM score on the test data

# %%
estimator.load('models/sally')

t_hat = estimator.evaluate_score(
    x='data_pp/samples/x_test.npy'
)
# Out:
# 16:20 madminer.ml.base     INFO    Loading model from models/sally
# 16:20 madminer.utils.vario INFO      Loading data_pp/samples/x_test.npy into RAM

# %% [markdown]
# Let's have a look at the estimated score and how it is related to the observables:

# %%
x = np.load('data_pp/samples/x_test.npy')

fig = plt.figure(figsize=(10,4))

for i in range(2):
    
    ax = plt.subplot(1,2,i+1)

    sc = plt.scatter(x[:,0], x[:,1], c=t_hat[:,i], s=25., cmap='viridis', vmin=-1., vmax=1.)
    cbar = plt.colorbar(sc)

    cbar.set_label(r'$\hat{t}_' + str(i) + r'(x | \theta_{ref})$')
    plt.xlabel(r'$p_{T,j1}$ [GeV]')
    plt.ylabel(r'$\Delta \phi_{jj}$')
    plt.xlim(10.,300.)
    plt.ylim(-3.15,3.15)
    
plt.tight_layout()
plt.show()
